# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Start Count
record_count = 1
set_count = 1

# Basic url API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
# Count amount of unique cities
len(cities)
# Out:
# 772

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in 50s
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# API request for each city 
    try:
       
        # Add the JSON data
        city_weather = requests.get(city_url).json()

        
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    except: 
        print("City not found. Skipping")
        pass

    # Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | kruisfontein
# Processing Record 5 of Set 1 | balikpapan
# Processing Record 6 of Set 1 | kostino
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping
# Processing Record 8 of Set 1 | ust-ilimsk
# Processing Record 9 of Set 1 | itoman
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | upornaya
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | bluefields
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | ulladulla
# Processing Record 19 of Set 1 | balakhta
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | zavodoukovsk
# Processing Record 22 of Set 1 | guaramirim
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | wajir
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | henties bay
# Processing Record 28 of Set 1 | christchurch
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | mount gambier
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | porto santo
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | fallon
# Processing Record 39 of Set 1 | maniitsoq
# Processing Record 40 of Set 1 | baiyin
# Processing Record 41 of Set 1 | laguna
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | weligama
# Processing Record 44 of Set 1 | saint anthony
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | kuching
# Processing Record 1 of Set 2 | san anselmo
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | ust-tsilma
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | khani
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | matagami
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | grindavik
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | bozdar
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | parana
# Processing Record 16 of Set 2 | tumannyy
# City not found. Skipping
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | lorengau
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | kabale
# Processing Record 23 of Set 2 | ransang
# Processing Record 24 of Set 2 | saeby
# Processing Record 25 of Set 2 | saint-augustin
# Processing Record 26 of Set 2 | westport
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | miguel hidalgo
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | duluth
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | salinopolis
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | samarai
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | putina
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | katherine
# Processing Record 41 of Set 2 | sal rei
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | barra
# Processing Record 44 of Set 2 | nabire
# Processing Record 45 of Set 2 | jalu
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | grand river south east
# City not found. Skipping
# Processing Record 49 of Set 2 | lompoc
# Processing Record 50 of Set 2 | ahipara
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | kuche
# City not found. Skipping
# Processing Record 3 of Set 3 | douentza
# Processing Record 4 of Set 3 | chany
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | saleaula
# City not found. Skipping
# Processing Record 8 of Set 3 | lomianki
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | verkh-usugli
# Processing Record 11 of Set 3 | la ronge
# Processing Record 12 of Set 3 | turayf
# Processing Record 13 of Set 3 | wanning
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | asekeyevo
# Processing Record 16 of Set 3 | barbar
# City not found. Skipping
# Processing Record 17 of Set 3 | gurskoye
# City not found. Skipping
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | wageningen
# Processing Record 20 of Set 3 | hof
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | konstantinovka
# Processing Record 23 of Set 3 | karamay
# City not found. Skipping
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | ilhabela
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 33 of Set 3 | resistencia
# Processing Record 34 of Set 3 | kidal
# Processing Record 35 of Set 3 | qasigiannguit
# Processing Record 36 of Set 3 | hauterive
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | manta
# Processing Record 39 of Set 3 | adilabad
# Processing Record 40 of Set 3 | bad windsheim
# Processing Record 41 of Set 3 | sedona
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | gizo
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | chapais
# Processing Record 48 of Set 3 | kuloy
# Processing Record 49 of Set 3 | baracoa
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 1 of Set 4 | soller
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | kashi
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | am timan
# Processing Record 7 of Set 4 | miri
# Processing Record 8 of Set 4 | zhigansk
# Processing Record 9 of Set 4 | koslan
# Processing Record 10 of Set 4 | iranshahr
# Processing Record 11 of Set 4 | napierville
# Processing Record 12 of Set 4 | college
# Processing Record 13 of Set 4 | itarema
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | morros
# Processing Record 16 of Set 4 | karwar
# Processing Record 17 of Set 4 | flinders
# Processing Record 18 of Set 4 | apollonia
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping
# Processing Record 20 of Set 4 | belmonte
# Processing Record 21 of Set 4 | ryotsu
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | avera
# Processing Record 24 of Set 4 | waingapu
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | karaul
# City not found. Skipping
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | trat
# Processing Record 29 of Set 4 | pathein
# Processing Record 30 of Set 4 | yar-sale
# Processing Record 31 of Set 4 | gat
# Processing Record 32 of Set 4 | ashland
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping
# Processing Record 34 of Set 4 | pecos
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | fort nelson
# Processing Record 37 of Set 4 | vanimo
# Processing Record 38 of Set 4 | kondinskoye
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | santa rosa
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | batticaloa
# Processing Record 43 of Set 4 | cockburn town
# Processing Record 44 of Set 4 | bouar
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | cypress
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | comodoro rivadavia
# Processing Record 49 of Set 4 | paamiut
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | bathsheba
# Processing Record 3 of Set 5 | san carlos de bariloche
# Processing Record 4 of Set 5 | vikulovo
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | verkhnevilyuysk
# Processing Record 10 of Set 5 | tupik
# Processing Record 11 of Set 5 | louisbourg
# City not found. Skipping
# Processing Record 12 of Set 5 | dezhou
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | praia da vitoria
# Processing Record 15 of Set 5 | geresk
# City not found. Skipping
# Processing Record 16 of Set 5 | la algaba
# Processing Record 17 of Set 5 | suslonger
# Processing Record 18 of Set 5 | katesh
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | one hundred mile house
# City not found. Skipping
# Processing Record 21 of Set 5 | tiznit
# Processing Record 22 of Set 5 | lexington
# Processing Record 23 of Set 5 | san juan
# Processing Record 24 of Set 5 | broken hill
# Processing Record 25 of Set 5 | evensk
# Processing Record 26 of Set 5 | anito
# Processing Record 27 of Set 5 | paveh
# Processing Record 28 of Set 5 | taltal
# Processing Record 29 of Set 5 | grand baie
# Processing Record 30 of Set 5 | beloha
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | teya
# Processing Record 33 of Set 5 | tasiilaq
# Processing Record 34 of Set 5 | eyl
# Processing Record 35 of Set 5 | lakatoro
# Processing Record 36 of Set 5 | camacha
# Processing Record 37 of Set 5 | santa luzia
# Processing Record 38 of Set 5 | agbor
# Processing Record 39 of Set 5 | anadyr
# Processing Record 40 of Set 5 | san quintin
# Processing Record 41 of Set 5 | mitzic
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | kangaatsiaq
# Processing Record 44 of Set 5 | torit
# Processing Record 45 of Set 5 | tuktoyaktuk
# Processing Record 46 of Set 5 | sandnessjoen
# Processing Record 47 of Set 5 | biak
# Processing Record 48 of Set 5 | ler
# Processing Record 49 of Set 5 | doka
# Processing Record 50 of Set 5 | buala
# Processing Record 1 of Set 6 | solton
# Processing Record 2 of Set 6 | elizabeth city
# Processing Record 3 of Set 6 | kaitangata
# Processing Record 4 of Set 6 | mbekenyera
# Processing Record 5 of Set 6 | yinchuan
# Processing Record 6 of Set 6 | pipri
# Processing Record 7 of Set 6 | varhaug
# Processing Record 8 of Set 6 | sioux lookout
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | sulzbach-rosenberg
# Processing Record 11 of Set 6 | kothapet
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | shaunavon
# Processing Record 14 of Set 6 | mana
# Processing Record 15 of Set 6 | butler
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | suntar
# Processing Record 18 of Set 6 | asosa
# Processing Record 19 of Set 6 | tchollire
# Processing Record 20 of Set 6 | morristown
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | kabalo
# Processing Record 23 of Set 6 | muyezerskiy
# Processing Record 24 of Set 6 | srisailam
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | nushki
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | kande
# Processing Record 30 of Set 6 | bayanday
# Processing Record 31 of Set 6 | young
# Processing Record 32 of Set 6 | fermo
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | karkaralinsk
# City not found. Skipping
# Processing Record 35 of Set 6 | sola
# Processing Record 36 of Set 6 | faanui
# Processing Record 37 of Set 6 | xinyu
# Processing Record 38 of Set 6 | sept-iles
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | alto araguaia
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | bubaque
# Processing Record 44 of Set 6 | ngozi
# Processing Record 45 of Set 6 | kirovskiy
# Processing Record 46 of Set 6 | san pedro
# Processing Record 47 of Set 6 | fairbanks
# Processing Record 48 of Set 6 | sao mateus do sul
# Processing Record 49 of Set 6 | sao gabriel da cachoeira
# Processing Record 50 of Set 6 | norman wells
# Processing Record 1 of Set 7 | longyearbyen
# Processing Record 2 of Set 7 | moramanga
# Processing Record 3 of Set 7 | grand-santi
# Processing Record 4 of Set 7 | mitsamiouli
# Processing Record 5 of Set 7 | oranjemund
# Processing Record 6 of Set 7 | bagdarin
# Processing Record 7 of Set 7 | dillon
# Processing Record 8 of Set 7 | harper
# Processing Record 9 of Set 7 | qaqortoq
# Processing Record 10 of Set 7 | aswan
# Processing Record 11 of Set 7 | san-pedro
# Processing Record 12 of Set 7 | shagonar
# Processing Record 13 of Set 7 | birkeland
# Processing Record 14 of Set 7 | moose factory
# Processing Record 15 of Set 7 | winslow
# Processing Record 16 of Set 7 | cuxhaven
# Processing Record 17 of Set 7 | livada
# Processing Record 18 of Set 7 | umzimvubu
# City not found. Skipping
# Processing Record 19 of Set 7 | sabha
# Processing Record 20 of Set 7 | krasnorechenskiy
# Processing Record 21 of Set 7 | middlesbrough
# Processing Record 22 of Set 7 | the valley
# Processing Record 23 of Set 7 | nantucket
# Processing Record 24 of Set 7 | alyangula
# Processing Record 25 of Set 7 | berwick
# Processing Record 26 of Set 7 | pasan
# Processing Record 27 of Set 7 | barh
# Processing Record 28 of Set 7 | mizdah
# Processing Record 29 of Set 7 | puerto quijarro
# Processing Record 30 of Set 7 | kharabali
# Processing Record 31 of Set 7 | cosala
# Processing Record 32 of Set 7 | marawi
# Processing Record 33 of Set 7 | moron
# Processing Record 34 of Set 7 | polunochnoye
# Processing Record 35 of Set 7 | nanortalik
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | ambon
# Processing Record 38 of Set 7 | umm durman
# City not found. Skipping
# Processing Record 39 of Set 7 | bolungarvik
# City not found. Skipping
# Processing Record 40 of Set 7 | xiuyan
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | kahului
# Processing Record 43 of Set 7 | creel
# Processing Record 44 of Set 7 | ndele
# Processing Record 45 of Set 7 | santa cruz de tenerife
# Processing Record 46 of Set 7 | lodwar
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | ornskoldsvik
# Processing Record 49 of Set 7 | conil
# Processing Record 50 of Set 7 | havoysund
# Processing Record 1 of Set 8 | chillicothe
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | oktyabrskiy
# Processing Record 4 of Set 8 | okha
# Processing Record 5 of Set 8 | sitka
# Processing Record 6 of Set 8 | gawler
# Processing Record 7 of Set 8 | sao felix do xingu
# Processing Record 8 of Set 8 | campos
# Processing Record 9 of Set 8 | praia
# Processing Record 10 of Set 8 | aksu
# Processing Record 11 of Set 8 | manadhoo
# Processing Record 12 of Set 8 | tibiri
# Processing Record 13 of Set 8 | agirish
# Processing Record 14 of Set 8 | yeppoon
# Processing Record 15 of Set 8 | sao miguel do araguaia
# Processing Record 16 of Set 8 | pousat
# City not found. Skipping
# Processing Record 17 of Set 8 | la argentina
# Processing Record 18 of Set 8 | bandarbeyla
# Processing Record 19 of Set 8 | madang
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | parit buntar
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | luanda
# Processing Record 24 of Set 8 | poum
# Processing Record 25 of Set 8 | imeni poliny osipenko
# Processing Record 26 of Set 8 | dingle
# Processing Record 27 of Set 8 | ruatoria
# City not found. Skipping
# Processing Record 28 of Set 8 | port hueneme
# Processing Record 29 of Set 8 | laurel
# Processing Record 30 of Set 8 | rio grande
# Processing Record 31 of Set 8 | talnakh
# Processing Record 32 of Set 8 | uyemskiy
# Processing Record 33 of Set 8 | qandala
# Processing Record 34 of Set 8 | urdzhar
# City not found. Skipping
# Processing Record 35 of Set 8 | tapiramuta
# Processing Record 36 of Set 8 | tunduru
# City not found. Skipping
# Processing Record 37 of Set 8 | miraflores
# Processing Record 38 of Set 8 | tulun
# Processing Record 39 of Set 8 | dusti
# Processing Record 40 of Set 8 | manakara
# Processing Record 41 of Set 8 | tomatlan
# Processing Record 42 of Set 8 | tromso
# Processing Record 43 of Set 8 | suriapet
# Processing Record 44 of Set 8 | las vegas
# Processing Record 45 of Set 8 | caska
# Processing Record 46 of Set 8 | bongor
# Processing Record 47 of Set 8 | starup
# Processing Record 48 of Set 8 | tolaga bay
# Processing Record 49 of Set 8 | maragogi
# Processing Record 50 of Set 8 | moses lake
# Processing Record 1 of Set 9 | palabuhanratu
# City not found. Skipping
# Processing Record 2 of Set 9 | arroyo
# Processing Record 3 of Set 9 | xining
# Processing Record 4 of Set 9 | tacoronte
# Processing Record 5 of Set 9 | kavieng
# Processing Record 6 of Set 9 | ilulissat
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | tezu
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | taoudenni
# Processing Record 11 of Set 9 | alice springs
# Processing Record 12 of Set 9 | prachuap khiri khan
# Processing Record 13 of Set 9 | nouadhibou
# Processing Record 14 of Set 9 | jaca
# Processing Record 15 of Set 9 | forbes
# Processing Record 16 of Set 9 | yuancheng
# Processing Record 17 of Set 9 | calvinia
# Processing Record 18 of Set 9 | warqla
# City not found. Skipping
# Processing Record 19 of Set 9 | kununurra
# Processing Record 20 of Set 9 | strezhevoy
# Processing Record 21 of Set 9 | galgani
# City not found. Skipping
# Processing Record 22 of Set 9 | sataua
# City not found. Skipping
# Processing Record 23 of Set 9 | ust-nera
# Processing Record 24 of Set 9 | tura
# Processing Record 25 of Set 9 | caravelas
# Processing Record 26 of Set 9 | kandrian
# Processing Record 27 of Set 9 | normal
# Processing Record 28 of Set 9 | deputatskiy
# Processing Record 29 of Set 9 | san policarpo
# Processing Record 30 of Set 9 | port macquarie
# Processing Record 31 of Set 9 | laguna de duero
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | zhanatas
# City not found. Skipping
# Processing Record 34 of Set 9 | quballat
# Processing Record 35 of Set 9 | asfi
# Processing Record 36 of Set 9 | egvekinot
# Processing Record 37 of Set 9 | seguela
# Processing Record 38 of Set 9 | cheyenne
# Processing Record 39 of Set 9 | nago
# Processing Record 40 of Set 9 | napasar
# Processing Record 41 of Set 9 | palana
# Processing Record 42 of Set 9 | carutapera
# Processing Record 43 of Set 9 | bud
# Processing Record 44 of Set 9 | teguise
# Processing Record 45 of Set 9 | saravan
# Processing Record 46 of Set 9 | otane
# Processing Record 47 of Set 9 | mouzakion
# City not found. Skipping
# Processing Record 48 of Set 9 | mae sai
# Processing Record 49 of Set 9 | mporokoso
# Processing Record 50 of Set 9 | ridgecrest
# Processing Record 1 of Set 10 | artyk
# City not found. Skipping
# Processing Record 2 of Set 10 | kedrovyy
# Processing Record 3 of Set 10 | sentyabrskiy
# City not found. Skipping
# Processing Record 4 of Set 10 | ewo
# Processing Record 5 of Set 10 | axim
# Processing Record 6 of Set 10 | harnosand
# Processing Record 7 of Set 10 | skibbereen
# Processing Record 8 of Set 10 | half moon bay
# Processing Record 9 of Set 10 | lebedinyy
# Processing Record 10 of Set 10 | atambua
# Processing Record 11 of Set 10 | dicabisagan
# Processing Record 12 of Set 10 | pangnirtung
# Processing Record 13 of Set 10 | ribeira brava
# Processing Record 14 of Set 10 | saint-francois
# Processing Record 15 of Set 10 | mindelo
# Processing Record 16 of Set 10 | ha tinh
# Processing Record 17 of Set 10 | ngukurr
# City not found. Skipping
# Processing Record 18 of Set 10 | port victoria
# Processing Record 19 of Set 10 | narsaq
# Processing Record 20 of Set 10 | lauterbach
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | bobrovka
# Processing Record 23 of Set 10 | wamba
# Processing Record 24 of Set 10 | ibra
# Processing Record 25 of Set 10 | brae
# Processing Record 26 of Set 10 | kawalu
# Processing Record 27 of Set 10 | ilkal
# Processing Record 28 of Set 10 | san andres
# Processing Record 29 of Set 10 | bolgatanga
# Processing Record 30 of Set 10 | shetpe
# Processing Record 31 of Set 10 | kautokeino
# Processing Record 32 of Set 10 | torbat-e jam
# Processing Record 33 of Set 10 | rockhampton
# Processing Record 34 of Set 10 | karratha
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | oranjestad
# Processing Record 37 of Set 10 | troy
# Processing Record 38 of Set 10 | epe
# Processing Record 39 of Set 10 | labuan
# Processing Record 40 of Set 10 | morehead
# Processing Record 41 of Set 10 | turukhansk
# Processing Record 42 of Set 10 | mnogovershinnyy
# Processing Record 43 of Set 10 | bilibino
# Processing Record 44 of Set 10 | aden
# Processing Record 45 of Set 10 | quatre cocos
# Processing Record 46 of Set 10 | high level
# Processing Record 47 of Set 10 | muravlenko
# Processing Record 48 of Set 10 | tuburan
# Processing Record 49 of Set 10 | banda aceh
# Processing Record 50 of Set 10 | mangrol
# Processing Record 1 of Set 11 | sisimiut
# Processing Record 2 of Set 11 | keflavik
# Processing Record 3 of Set 11 | knysna
# Processing Record 4 of Set 11 | smithers
# Processing Record 5 of Set 11 | vicuna
# Processing Record 6 of Set 11 | aksum
# Processing Record 7 of Set 11 | juegang
# Processing Record 8 of Set 11 | nchelenge
# Processing Record 9 of Set 11 | orocue
# Processing Record 10 of Set 11 | souillac
# Processing Record 11 of Set 11 | cayenne
# Processing Record 12 of Set 11 | santiago
# Processing Record 13 of Set 11 | azul
# Processing Record 14 of Set 11 | baghdad
# Processing Record 15 of Set 11 | ketchikan
# Processing Record 16 of Set 11 | korla
# Processing Record 17 of Set 11 | bangassou
# Processing Record 18 of Set 11 | tiarei
# Processing Record 19 of Set 11 | ostrovnoy
# Processing Record 20 of Set 11 | vestmannaeyjar
# Processing Record 21 of Set 11 | luancheng
# Processing Record 22 of Set 11 | auburn
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | manokwari
# Processing Record 25 of Set 11 | shimoda
# Processing Record 26 of Set 11 | gorontalo
# Processing Record 27 of Set 11 | rocha
# Processing Record 28 of Set 11 | aiken
# Processing Record 29 of Set 11 | rey bouba
# Processing Record 30 of Set 11 | muscle shoals
# Processing Record 31 of Set 11 | mutuipe
# Processing Record 32 of Set 11 | mankono
# Processing Record 33 of Set 11 | lianran
# Processing Record 34 of Set 11 | pringsewu
# Processing Record 35 of Set 11 | dalinghe
# City not found. Skipping
# Processing Record 36 of Set 11 | tigil
# Processing Record 37 of Set 11 | gorele
# Processing Record 38 of Set 11 | kindu
# Processing Record 39 of Set 11 | chifeng
# Processing Record 40 of Set 11 | buhe
# Processing Record 41 of Set 11 | gizeh
# Processing Record 42 of Set 11 | thanatpin
# Processing Record 43 of Set 11 | singkang
# Processing Record 44 of Set 11 | sangin
# Processing Record 45 of Set 11 | pacific grove
# Processing Record 46 of Set 11 | kattivakkam
# Processing Record 47 of Set 11 | juneau
# Processing Record 48 of Set 11 | ternate
# Processing Record 49 of Set 11 | burica
# City not found. Skipping
# Processing Record 50 of Set 11 | kamaishi
# Processing Record 1 of Set 12 | pemangkat
# Processing Record 2 of Set 12 | lumeje
# Processing Record 3 of Set 12 | shellbrook
# Processing Record 4 of Set 12 | caucaia
# Processing Record 5 of Set 12 | niquero
# Processing Record 6 of Set 12 | davidson
# Processing Record 7 of Set 12 | cajimos
# Processing Record 8 of Set 12 | birao
# Processing Record 9 of Set 12 | grand gaube
# Processing Record 10 of Set 12 | mandera
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | motygino
# Processing Record 13 of Set 12 | tochio
# Processing Record 14 of Set 12 | sakaraha
# Processing Record 15 of Set 12 | leirvik
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | zyryanka
# Processing Record 18 of Set 12 | malwan
# City not found. Skipping
# Processing Record 19 of Set 12 | bend
# Processing Record 20 of Set 12 | nalut
# Processing Record 21 of Set 12 | zeya
# Processing Record 22 of Set 12 | buritis
# Processing Record 23 of Set 12 | shubarkuduk
# Processing Record 24 of Set 12 | askarovo
# Processing Record 25 of Set 12 | sorvag
# City not found. Skipping
# Processing Record 26 of Set 12 | garden city
# Processing Record 27 of Set 12 | rolim de moura
# City not found. Skipping
# Processing Record 28 of Set 12 | sarkand
# Processing Record 29 of Set 12 | along
# Processing Record 30 of Set 12 | agucadoura
# Processing Record 31 of Set 12 | los llanos de aridane
# Processing Record 32 of Set 12 | olenino
# Processing Record 33 of Set 12 | manbij
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | tabiauea
# City not found. Skipping
# Processing Record 36 of Set 12 | hambantota
# Processing Record 37 of Set 12 | hualmay
# Processing Record 38 of Set 12 | jacareacanga
# Processing Record 39 of Set 12 | jutai
# Processing Record 40 of Set 12 | kachug
# Processing Record 41 of Set 12 | taiyuan
# Processing Record 42 of Set 12 | honningsvag
# Processing Record 43 of Set 12 | perth
# Processing Record 44 of Set 12 | upata
# Processing Record 45 of Set 12 | bilma
# Processing Record 46 of Set 12 | sao jose da coroa grande
# Processing Record 47 of Set 12 | kutum
# Processing Record 48 of Set 12 | milkovo
# Processing Record 49 of Set 12 | compiegne
# Processing Record 50 of Set 12 | yulara
# Processing Record 1 of Set 13 | keti bandar
# Processing Record 2 of Set 13 | chipinge
# Processing Record 3 of Set 13 | mayo
# Processing Record 4 of Set 13 | bemidji
# Processing Record 5 of Set 13 | havre-saint-pierre
# Processing Record 6 of Set 13 | galiwinku
# City not found. Skipping
# Processing Record 7 of Set 13 | bressuire
# Processing Record 8 of Set 13 | carmelo
# Processing Record 9 of Set 13 | pervomayskoye
# Processing Record 10 of Set 13 | rudnogorsk
# Processing Record 11 of Set 13 | burns lake
# Processing Record 12 of Set 13 | poya
# Processing Record 13 of Set 13 | rawson
# Processing Record 14 of Set 13 | utiroa
# City not found. Skipping
# Processing Record 15 of Set 13 | gabu
# Processing Record 16 of Set 13 | bur gabo
# City not found. Skipping
# Processing Record 17 of Set 13 | lang suan
# Processing Record 18 of Set 13 | kiunga
# Processing Record 19 of Set 13 | shalya
# Processing Record 20 of Set 13 | nagaur
# Processing Record 21 of Set 13 | ranau
# Processing Record 22 of Set 13 | lithgow
# Processing Record 23 of Set 13 | kloulklubed
# Processing Record 24 of Set 13 | hofn
# Processing Record 25 of Set 13 | manaure
# Processing Record 26 of Set 13 | okato
# Processing Record 27 of Set 13 | sangar
# Processing Record 28 of Set 13 | north myrtle beach
# Processing Record 29 of Set 13 | rayadrug
# Processing Record 30 of Set 13 | tyukod
# Processing Record 31 of Set 13 | makokou
# Processing Record 32 of Set 13 | samalaeulu
# City not found. Skipping
# Processing Record 33 of Set 13 | kungalv
# Processing Record 34 of Set 13 | le port
# Processing Record 35 of Set 13 | storsteinnes
# Processing Record 36 of Set 13 | tautira
# Processing Record 37 of Set 13 | puerto ayacucho
# Processing Record 38 of Set 13 | asau
# Processing Record 39 of Set 13 | koyilandi
# City not found. Skipping
# Processing Record 40 of Set 13 | kirakira
# Processing Record 41 of Set 13 | santa rosalia
# Processing Record 42 of Set 13 | takoradi
# Processing Record 43 of Set 13 | mayumba
# Processing Record 44 of Set 13 | wooster
# Processing Record 45 of Set 13 | mrirt
# City not found. Skipping
# Processing Record 46 of Set 13 | antalaha
# Processing Record 47 of Set 13 | paradwip
# City not found. Skipping
# Processing Record 48 of Set 13 | kissidougou
# Processing Record 49 of Set 13 | redcliffe
# Processing Record 50 of Set 13 | mezen
# Processing Record 1 of Set 14 | mantua
# Processing Record 2 of Set 14 | manicore
# Processing Record 3 of Set 14 | changji
# Processing Record 4 of Set 14 | mahaicony
# City not found. Skipping
# Processing Record 5 of Set 14 | auki
# Processing Record 6 of Set 14 | kushmurun
# Processing Record 7 of Set 14 | rudbar
# Processing Record 8 of Set 14 | lensk
# Processing Record 9 of Set 14 | lafiagi
# Processing Record 10 of Set 14 | colac
# Processing Record 11 of Set 14 | atar
# Processing Record 12 of Set 14 | agadez
# Processing Record 13 of Set 14 | black river
# Processing Record 14 of Set 14 | aksay
# Processing Record 15 of Set 14 | wenling
# Processing Record 16 of Set 14 | inirida
# Processing Record 17 of Set 14 | lake jackson
# Processing Record 18 of Set 14 | gillette
# Processing Record 19 of Set 14 | sosnovo-ozerskoye
# Processing Record 20 of Set 14 | yaan
# Processing Record 21 of Set 14 | helong
# Processing Record 22 of Set 14 | dalvik
# Processing Record 23 of Set 14 | colares
# Processing Record 24 of Set 14 | kyle of lochalsh
# City not found. Skipping
# Processing Record 25 of Set 14 | cherlak
# Processing Record 26 of Set 14 | voh
# Processing Record 27 of Set 14 | nicoya
# Processing Record 28 of Set 14 | lufilufi
# Processing Record 29 of Set 14 | attawapiskat
# City not found. Skipping
# Processing Record 30 of Set 14 | lewisporte
# Processing Record 31 of Set 14 | gulshat
# City not found. Skipping
# Processing Record 32 of Set 14 | nioro
# Processing Record 33 of Set 14 | vawkavysk
# Processing Record 34 of Set 14 | tibagi
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | masunga
# Processing Record 37 of Set 14 | pithoragarh
# Processing Record 38 of Set 14 | aripuana
# Processing Record 39 of Set 14 | sainte-anne-des-monts
# Processing Record 40 of Set 14 | hatfield
# Processing Record 41 of Set 14 | haapu
# City not found. Skipping
# Processing Record 42 of Set 14 | san ramon
# Processing Record 43 of Set 14 | konde
# Processing Record 44 of Set 14 | linxia
# Processing Record 45 of Set 14 | toliary
# City not found. Skipping
# Processing Record 46 of Set 14 | katsuura
# Processing Record 47 of Set 14 | mantena
# Processing Record 48 of Set 14 | santa cruz
# Processing Record 49 of Set 14 | ilheus
# Processing Record 50 of Set 14 | nopalucan
# Processing Record 1 of Set 15 | naze
# Processing Record 2 of Set 15 | nouakchott
# Processing Record 3 of Set 15 | ponte san nicolo
# Processing Record 4 of Set 15 | cartagena
# Processing Record 5 of Set 15 | tutoia
# Processing Record 6 of Set 15 | saryg-sep
# Processing Record 7 of Set 15 | zambezi
# Processing Record 8 of Set 15 | nelson
# Processing Record 9 of Set 15 | wewak
# Processing Record 10 of Set 15 | tlanalapa
# Processing Record 11 of Set 15 | russkiy kameshkir
# Processing Record 12 of Set 15 | neerijnen
# Processing Record 13 of Set 15 | altus
# Processing Record 14 of Set 15 | kapoeta
# Processing Record 15 of Set 15 | wuxue
# Processing Record 16 of Set 15 | kazalinsk
# City not found. Skipping
# Processing Record 17 of Set 15 | juarez
# Processing Record 18 of Set 15 | thunder bay
# Processing Record 19 of Set 15 | north bend
# Processing Record 20 of Set 15 | traverse city
# Processing Record 21 of Set 15 | malakal
# Processing Record 22 of Set 15 | ortakoy
# Processing Record 23 of Set 15 | rantepao
# Processing Record 24 of Set 15 | mao
# Processing Record 25 of Set 15 | parkes
# Processing Record 26 of Set 15 | valleyview
# Processing Record 27 of Set 15 | kollumerland
# City not found. Skipping
# Processing Record 28 of Set 15 | cherkasskoye
# Processing Record 29 of Set 15 | vanavara
# Processing Record 30 of Set 15 | bembereke
# Processing Record 31 of Set 15 | uppsala
# Processing Record 32 of Set 15 | tailai
# Processing Record 33 of Set 15 | turbat
# Processing Record 34 of Set 15 | najran
# Processing Record 35 of Set 15 | douglas
# Processing Record 36 of Set 15 | kamenskoye
# City not found. Skipping
# Processing Record 37 of Set 15 | meyungs
# City not found. Skipping
# Processing Record 38 of Set 15 | soyo
# Processing Record 39 of Set 15 | bangkalan
# Processing Record 40 of Set 15 | zaysan
# Processing Record 41 of Set 15 | magrath
# Processing Record 42 of Set 15 | kiama
# Processing Record 43 of Set 15 | trairi
# Processing Record 44 of Set 15 | aberlour
# City not found. Skipping
# Processing Record 45 of Set 15 | santa catarina de tepehuanes
# Processing Record 46 of Set 15 | bourail
# Processing Record 47 of Set 15 | kosh-agach
# Processing Record 48 of Set 15 | baruun-urt
# Processing Record 49 of Set 15 | iquique
# Processing Record 50 of Set 15 | navrongo
# Processing Record 1 of Set 16 | leiyang
# Processing Record 2 of Set 16 | bodmin
# Processing Record 3 of Set 16 | puerto rico
# Processing Record 4 of Set 16 | lincoln
# Processing Record 5 of Set 16 | wawa
# Processing Record 6 of Set 16 | martil
# Processing Record 7 of Set 16 | new castle
# Processing Record 8 of Set 16 | morant bay
# Processing Record 9 of Set 16 | longlac
# City not found. Skipping
# Processing Record 10 of Set 16 | ilinsko-podomskoye
# City not found. Skipping
# Processing Record 11 of Set 16 | kusye-aleksandrovskiy
# City not found. Skipping
# Processing Record 12 of Set 16 | gilgit
# Processing Record 13 of Set 16 | meulaboh
# Processing Record 14 of Set 16 | aykhal
# Processing Record 15 of Set 16 | havelock
# Processing Record 16 of Set 16 | khonuu
# City not found. Skipping
# Processing Record 17 of Set 16 | ahvaz
# Processing Record 18 of Set 16 | batagay
# Processing Record 19 of Set 16 | mukhen
# Processing Record 20 of Set 16 | naica
# Processing Record 21 of Set 16 | ostrowiec swietokrzyski
# Processing Record 22 of Set 16 | filadelfia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
